# %% [markdown]
# # PYTHON BASICS

# %%
#defining different data structures in python
a=set()
b={}
c=dict()
d=list()
e=1,
f=1
g=''
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
print(type(g))
print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
print(g)
# Out:
# <class 'set'>
# <class 'dict'>
# <class 'dict'>
# <class 'list'>
# <class 'tuple'>
# <class 'int'>
# <class 'str'>
# set()
# {}
# {}
# []
# (1,)
# 1

# %%
d=dict()

print(type(e),e,sep="")
# Out:
# <class 'tuple'>(1,)

# %%
str="hello\niamok"
print(str)
print(len(str))
print(r"hello\niamok")
print(len(r"hello\niamok"))
# Out:
# hello
# iamok
# 11
# hello\niamok
# 12

# %%
l=range(5)
for i in l:
  print(i**3)
  print(i)
# Out:
# 0
# 0
# 1
# 1
# 8
# 2
# 27
# 3
# 64
# 4

# %%
#printing cubes and squares of first 20 natural numbers
i=1
while   i<=20:
  print(i**3,i*i)
  i=i+1
# Out:
# 1 1
# 8 4
# 27 9
# 64 16
# 125 25
# 216 36
# 343 49
# 512 64
# 729 81
# 1000 100
# 1331 121
# 1728 144
# 2197 169
# 2744 196
# 3375 225
# 4096 256
# 4913 289
# 5832 324
# 6859 361
# 8000 400

# %%
for i in range(1,23,3):
  print(i)
# Out:
# 1
# 4
# 7
# 10
# 13
# 16
# 19
# 22

# %%
lscomp=[x**3 for x in range(4)]
print(lscomp)
stcomp={x**3 for x in range(4)}
print(stcomp)
tucomp=tuple([x**3 for x in range(4)])
print(tucomp)
# Out:
# [0, 1, 8, 27]
# {0, 1, 27, 8}
# (0, 1, 8, 27)

# %%
x = lambda a : a + 10
print(x(5))
# Out:
# 15

# %%
a=print("hello")
a
print(a)
# Out:
# hello
# None

# %%
def square(x):
    return x**2
print(square(45))
'''l=[1,2,3,4]
print(list(map(addfive,l)))
print(addfive(45))'''
# Out:
# 2025
# 'l=[1,2,3,4]\nprint(list(map(addfive,l)))\nprint(addfive(45))'

# %%
#printing cubes of numbers
def cube(y):
  return y**3
print(cube(13))
#printing cubes of first 10 numbers
for f in (range(0,11,1)):
  print (f**3)
  print (cube(f))
# Out:
# 2197
# 0
# 0
# 1
# 1
# 8
# 8
# 27
# 27
# 64
# 64
# 125
# 125
# 216
# 216
# 343
# 343
# 512
# 512
# 729
# 729
# 1000
# 1000

# %%
l=[1,2,34,4,5,"hii"]
for something in l:
  print(something*3)
# Out:
# 3
# 6
# 102
# 12
# 15
# hiihiihii

# %%
l=["d","2",1,3,2.0,{1,2},(1,3),{}]
for b in l:
  print(type(b))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'set'>
# <class 'tuple'>
# <class 'dict'>

# %%
x=list(map( lambda a : a**3,range(10)))
print(x)
x=list(map( lambda a : a,[1,"akhil",4.0]))
print(x)
x=tuple(map( lambda a : a*3,"iamok"))
print(x)
x=set(map( lambda a : a*4,{'hey',1,"ok"}))
print(x)
x=list(map( lambda a : a**3,range(10)))
print(list(map(lambda i :i*3,x)))
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729]
# [1, 'akhil', 4.0]
# ('iii', 'aaa', 'mmm', 'ooo', 'kkk')
# {'okokokok', 4, 'heyheyheyhey'}
# [0, 3, 24, 81, 192, 375, 648, 1029, 1536, 2187]

# %%
# a list contains both even and odd numbers.
seq = [0, 1, 2, 3, 5, 8, 13]

# result contains odd numbers of the list
result = filter(lambda x: x % 2 != 0, seq)
print(list(result))

# result contains even numbers of the list
result = filter(lambda x: x % 2 == 0, seq)
print(list(result))
# Out:
# [1, 3, 5, 13]
# [0, 2, 8]

# %%
result = list(map(lambda x: x % 2 != 0, seq))
print(result)
result = list(filter(lambda x: x % 2 != 0, seq))
print(result)
# Out:
# [False, True, False, True, True, False, True]
# [1, 3, 5, 13]

# %% [markdown]
# #KERAS PYTHON PREDICTION

# %%
#this programm uses an artificial reccurent neural network call Long Short Term memory
# to predict stocks closing price in future
#stock prediction using keras in python
#step1: statistical data analysis in googlesheets using google finance function.
#step2: data extraction or importing from the project.
#step3: creating data frames and using some operations like sorting and shape.
#step4: plotting the data using mathplotlib.pyplot and depicting it in different chart styles.
#step5: scaling the data
#step6: getting the train dataset(sample) from the testdata(whole population)
#step7: calculating the RSME(root mean square error), using models and calculating the output.
#step8: inverse scaling and presenting the predicted output.

# %%
#import libraries
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.layers import LSTM,Dense
from keras.models import Sequential
plt.style.use("fivethirtyeight")

# %%
from tensorflow import keras

# %%
# !pip install yfinance

# %%
#get the stock quote
import yfinance as yf
#ticker = (input("enter ticker syombol : ")).upper()
# df=pd.read_csv("data.csv")
# df
ticker = "WIPRO.NS"

# %%
dir(yf)

# %%
import requests

def get_company_details(symbol):
    api_key = "your_api_key_here"
    url = f"https://www.alphavantage.co/query?function=OVERVIEW&symbol={symbol}&apikey={api_key}"
    response = requests.get(url)
    data = response.json()
    return data

symbol = "TCS"
company_details = get_company_details(symbol)
print(len(company_details))
company_details

# %%
df = yf.download(ticker)#,start = "1970-01-01", end = "2023-01-01")
df['Date'] = df.index
df.index = np.arange(len(df))

# %%
#get the number of rows and number of columns
df.shape

# %%
#get the stock quote
#df=pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vTk8yeDphof25L0TZ-Q9ygxb0XCc4-nCsz8KuVw8EUgk6xS5UgyAhYuX-0igBdPJwDsL4wSaCwlGIj5/pub?gid=0&single=true&output=csv")
print(df.head())
print(df.columns)
print(df.dtypes)
print(round(df.describe(),3))

# %%
#visualize the closing price history
plt.figure(figsize=(24,8))
plt.title("Close+50-orange High+300-yellow open+550-green low+750-red volume/50000-black" , fontsize = 24)
plt.plot(df["Close"]+50,color="orange")
plt.plot(df["High"]+300,color='yellow')
plt.plot(df['Open']+550,color="green")
plt.plot(df["Low"]+750,color="red")
plt.plot(df["Volume"]/750000,color='black')
plt.xlabel("High", fontsize=18)
plt.ylabel("Close Price in RS", fontsize=18 )
plt.show()

# %%
# plt.figure(figsize=(24,8))
# plt.title("Close+50-orange High+300-yellow open+550-green low+750-red volume/50000-black" , fontsize = 24)
# plt.plot(df["Close"]+50,color="orange")
# plt.plot(df["High"],df["Low"])
# plt.plot(df["Date"].astype("str"),df["High"],color="blue")
# plt.plot(df["High"]+300,color='yellow')
# plt.plot(df['Open']+550,color="green")
# plt.plot(df["Low"]+750,color="red")
# plt.plot(df["Volume"]/7500000,color='black')
# plt.xlabel("Date", fontsize=18)
# plt.ylabel("Close Price in RS", fontsize=18 )
# plt.show()

# %%
plt.figure(figsize=(32,16))
plt.subplot(2,3,1)
plt.title("Close - orange   High - yellow   open - green    low - red   volume/50000-black" , fontsize = 24)
plt.plot(df["Date"], df["Close"] ,color="orange")
plt.xlabel("Date", fontsize=18)
plt.ylabel("Close Price in RS", fontsize=18 )
plt.subplot(2,3,2)
plt.plot(df["High"],df["Low"])
plt.xlabel("High", fontsize=18)
plt.ylabel("Low Price in RS", fontsize=18 )
plt.subplot(2,3,3)
# plt.plot(df["Date"].astype("str"),df["High"],color="blue")
plt.plot(df["Date"],df["High"],color='yellow')
plt.xlabel("Date", fontsize=18)
plt.ylabel("High Price in RS", fontsize=18 )
plt.subplot(2,3,4)
plt.plot(df["Date"],df['Open'],color="green")
plt.xlabel("Date", fontsize=18)
plt.ylabel("Open Price in RS", fontsize=18 )
plt.subplot(2,3,5)
plt.plot(df["Date"],df["Low"],color="red")
plt.xlabel("Date", fontsize=18)
plt.ylabel("Low Price in RS", fontsize=18 )
plt.subplot(2,3,6)
plt.plot(df["Date"],df["Volume"]/7500000,color='black')
plt.xlabel("Date", fontsize=18)
plt.ylabel("Volume", fontsize=18 )
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.plot(df["Close"],df["Volume"])
plt.show()

# %%
plt.plot(df["Close"],df["Date"])
plt.show()

# %%
plt.plot(df["Date"][::5000], df["Close"][::5000])
plt.show()

# %%
plt.plot(df["Date"][::500], df["Close"][::500])
plt.show()

# %%
plt.plot(df["Date"][::500][::-1],df['Close'][::500][::-1])
plt.show()

# %%
plt.plot(df["Close"][::500],df['Date'][::500])
plt.show()

# %%
plt.plot(df["Close"][::500][::-1],df["Date"][::500][::-1])
plt.show()

# %%
#visualize the closing price history
plt.figure(figsize=(16,8))

plt.subplot(1,2,1)
plt.plot(df["Volume"]/7500000)
plt.subplot(1,2,2)
plt.plot(df["Date"] ,df["Close"])
plt.xlabel("Date", fontsize=18)
plt.ylabel("Close Price in RS and Volume /7500000", fontsize=18)
title = plt.title("Close Price History")
title.set_horizontalalignment("center")
plt.show()

# %%
dir(plt.title("hi hello"))
# Out:
# ['_PROPERTIES_EXCLUDED_FROM_SET',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_agg_filter',
#  '_alias_map',
#  '_alpha',
#  '_animated',
#  '_axes',
#  '_bbox_patch',
#  '_callbacks',
#  '_char_index_at',
#  '_charsize_cache',
#  '_clipon',
#  '_clippath',
#  '_cm_set',
#  '_color',
#  '_default_contains',
#  '_fontproperties',
#  '_fully_clipped_to_axes',
#  '_get_dist_to_box',
#  '_get_layout',
#  '_get_multialignment',
#  '_get_rendered_text_width',
#  '_get_wrap_line_width',
#  '_get_wrapped_text',
#  '_get_xy_display',
#  '_gid',
#  '_horizontalalignment',
#  '_in_layout',
# ...

# %%
#creating a new dataframe with only the Close column
data=df.filter(["Close"])
#convert the dataframe to numpy array
dataset=data.values
#get the number to train the model on
training_data_len=math.ceil(len(dataset)*.8)
training_data_len
# Out:
# 5756

# %%
#Scale the data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(dataset)
scaled_data
# Out:
# array([[4.96023166e-04],
#        [3.74618934e-04],
#        [4.26649366e-04],
#        ...,
#        [7.20076450e-01],
#        [7.26875123e-01],
#        [7.29233766e-01]])

# %%
#create the training dataset
#create the scaled training dataset
train_data= scaled_data[0: training_data_len , :]
#split the data into x train and y train
x_train = []
y_train = []
for i in range(60,len(train_data)):
  x_train.append(train_data[i-60:i,0])
  y_train.append(train_data[i,0])
  if i<=61:
    print(x_train)
    print(y_train)
    print()
# Out:
# [array([0.00049602, 0.00037462, 0.00042665, 0.00042665, 0.00042665,
#        0.00042665, 0.00042665, 0.00042873, 0.00042665, 0.00042665,
#        0.00042665, 0.00039196, 0.00039196, 0.00041971, 0.00039196,
#        0.00041971, 0.00039196, 0.00039196, 0.00039196, 0.00039196,
#        0.00039196, 0.00038   , 0.00038   , 0.00038   , 0.00042665,
#        0.00042665, 0.00039196, 0.00039196, 0.00039196, 0.00039196,
#        0.0004263 , 0.0004263 , 0.0004263 , 0.0004263 , 0.00049602,
#        0.00049602, 0.00049602, 0.00049602, 0.00049602, 0.00049602,
#        0.00049602, 0.00044399, 0.00049602, 0.00049602, 0.00049602,
#        0.00049602, 0.00049602, 0.00049602, 0.00049602, 0.00048735,
#        0.00048735, 0.00049602, 0.00039214, 0.00039214, 0.00041277,
#        0.00046134, 0.00046151, 0.00046151, 0.00046151, 0.00046151])]
# [0.00046150960565661376]
#
# [array([0.00049602, 0.00037462, 0.00042665, 0.00042665, 0.00042665,
#        0.00042665, 0.00042665, 0.00042873, 0.00042665, 0.00042665,
# ...

# %%
#convert the x train and y train to numpy arrays
x_train,y_train=np.array(x_train),np.array(y_train)

# %%
#Reshape the data
x_train=np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
x_train.shape
# Out:
# (5696, 60, 1)

# %%
#Build the LSTM model
model = Sequential()
model.add(LSTM(50,return_sequences= True,input_shape = (x_train.shape[1],1)))
model.add(LSTM(50,return_sequences= False))
model.add(Dense(25))
model.add(Dense(1))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#compile the model
model.compile(optimizer='adam', loss="mean_squared_error",)

# %%
#train the model
model.fit(x_train[::20],y_train[::20],batch_size=1,epochs=2)

# %%
#create the testing data set
#create a new array containing scales values from 1954 to 2517
test_data = scaled_data[training_data_len-60 :, :]
#creatiing data sets x_test and y_test
x_test=[]
y_test=dataset[training_data_len:,:]
for i in range(60,len(test_data)):
  x_test.append(test_data[i-60:i,0])

# %%
#convert the data to a numpy array
x_test=np.array(x_test)

# %%
#reshape the data
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1 ))

# %%
#get the model prediction
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step

# %%
#Get the room mean square error
rsme = np.sqrt(np.mean(predictions - y_test)**2)
rsme

# %%
#plot the data
train=data[:training_data_len]
valid=data[training_data_len : ]
valid["predictions"] = predictions
#visualize the data
plt.figure(figsize=(16,8))
plt.title("Model")
plt.xlabel("Date", fontsize = 18)
plt.ylabel("Close",fontsize= 18)
plt.plot(train["Close"])
plt.plot(valid[["Close","predictions"]])
plt.legend(["Train","Close","predictions"],loc="lower right")
plt.show()
# Out:
# <ipython-input-69-6fbfd4350852>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["predictions"] = predictions

# %%
#Show the valid and predicted values
valid

# %%
# #get the quote
# apple_quote=pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vTk8yeDphof25L0TZ-Q9ygxb0XCc4-nCsz8KuVw8EUgk6xS5UgyAhYuX-0igBdPJwDsL4wSaCwlGIj5/pub?gid=0&single=true&output=csv")
# #create a new dataframe
# new_df= apple_quote.filter(["Close"])
# #last 60days close value and convert it into array
# last_60_days=new_df[-60:].values
# #scale the data between 0 and 1
# last_60_days_scaled = scaler.transform(last_60_days)
# #create an empty list
# X_test =[]
# #append 60 values to X_test
# X_test.append(last_60_days_scaled)
# #convert the X_test df to array
# X_test=np.array(X_test)
# #reshape the data
# X_test =np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
# #get the predicted scale value
# pred_price = model.predict(X_test)
# #undo the scaling
# pred_price= scaler.inverse_transform(pred_price)
# print(pred_price)

# %%
#get the quote
#######apple_quote=pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vTk8yeDphof25L0TZ-Q9ygxb0XCc4-nCsz8KuVw8EUgk6xS5UgyAhYuX-0igBdPJwDsL4wSaCwlGIj5/pub?gid=0&single=true&output=csv")
apple_quote = df
#create a new dataframe
new_df= apple_quote.filter(["Close"])
#last 60days close value and convert it into array
last_60_days=new_df[-60:].values
#scale the data between 0 and 1
last_60_days_scaled = scaler.transform(last_60_days)
#create an empty list
X_test =[]
#append 60 values to X_test
X_test.append(last_60_days_scaled)
#convert the X_test df to array
X_test=np.array(X_test)
#reshape the data
X_test =np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
#get the predicted scale value
pred_price = model.predict(X_test)
#undo the scaling
pred_price= scaler.inverse_transform(pred_price)
print(pred_price)
